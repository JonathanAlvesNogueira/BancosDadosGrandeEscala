# %%
import pandas as pd
import numpy as np
import random 
tamanho_base = 400000

# %% [markdown]
# # Gera a Base do Santander - Visão Produtos

# %%
# define quantos registros vai ter a base

# Gera o tipo de pessoa aleatoriamente
tipo_pessoa = np.random.choice(['PF', 'PJ'], size=tamanho_base)

#  gera o cpf_cnpj aleatoriamente
def gera_cpf_sem_dac():
    cpf = ''.join([str(random.randint(0, 9)) for i in range(9)])
    return cpf

cpf_cnpj = [ gera_cpf_sem_dac() for i in range(tamanho_base)]

renda_faturamento = np.random.choice([np.random.randint(1000, 10000), np.random.randint(10000,50000), np.random.randint(50000, 100000)], size=tamanho_base, p=[0.7, 0.2, 0.1])

outro_banco_cliente = np.random.choice(['Nubank', 'C6', 'Bradesco', 'Santander', 'Itau', 'Inter'], size=tamanho_base)

bad30 = np.random.randint(0, 2, size=tamanho_base)

serasa_score = np.random.randint(0, 999, size=tamanho_base)

tipo_bem = np.random.choice(['Veículos', 'Motos', 'Imóveis', 'Pesados'], size=tamanho_base)

valor_do_bem = [np.random.randint(5000, 10000) if bem == 'Motos' else np.random.randint(50000, 200000) if bem == 'Veículos' else np.random.randint(100000, 500000) if bem == 'Imóveis' else 
                np.random.randint(50000, 300000) for bem in tipo_bem]

fl_cliente_outro_produto = np.random.randint(0, 2, size=tamanho_base)

dias_atraso = np.random.choice( [0, np.random.randint(1, 540)], size=tamanho_base, p=[0.8,0.2])

# %%
# Junta todas as colunas de 10.000.000 de clientes que possuem Produtos Financeiros no Santander (Consorcio, Financiamento)
data = {
    'CPF_CNPJ': cpf_cnpj,
    'Renda_faturamento': renda_faturamento,
    'Outro_banco_cliente': outro_banco_cliente,
    'Bad30': bad30,
    'Serasa_score': serasa_score,
    'Tipo_bem': tipo_bem,
    'Valor_do_bem': valor_do_bem,
    'FL_cliente_outro_produto': fl_cliente_outro_produto
    ,'TIPO_PESSOA': tipo_pessoa
    ,'DIAS_ATRASO': dias_atraso
}


df_base_unica = pd.DataFrame(data)
display(df_base_unica)
# Out:
#          CPF_CNPJ  Renda_faturamento Outro_banco_cliente  Bad30  Serasa_score  \
# 0       155907201               7983                  C6      1           889
# 1       382250632              27342            Bradesco      1           866
# 2       349145899              27342            Bradesco      1           597
# 3       751489071               7983              Nubank      1           540
# 4       257310413               7983            Bradesco      0           990
# ...           ...                ...                 ...    ...           ...
# 399995  088847205               7983            Bradesco      0            72
# 399996  888130488               7983           Santander      0           541
# 399997  033478755              97313                  C6      1           267
# 399998  269702184               7983               Inter      1            37
# 399999  537488892               7983           Santander      1           620
#
#         Tipo_bem  Valor_do_bem  FL_cliente_outro_produto TIPO_PESSOA  \
# 0        Pesados        102816                         0          PJ
# 1        Imóveis        476402                         1          PF
# 2        Imóveis        180202                         1          PJ
# 3          Motos          7785                         0          PF
# 4        Imóveis        406027                         0          PF
# ...          ...           ...                       ...         ...
# 399995  Veículos         51978                         1          PJ
# 399996  Veículos        103730                         1          PJ
# 399997   Imóveis        448625                         1          PF
# 399998   Imóveis        165625                         1          PJ
# 399999   Pesados         72611                         1          PF
#
#         DIAS_ATRASO
# 0                 0
# 1                 0
# 2               117
# 3                 0
# 4                 0
# ...             ...
# 399995            0
# 399996            0
# 399997            0
# 399998            0
# 399999          117
#
# [400000 rows x 10 columns]

# %% [markdown]
# ## Base de Contratação

# %%
from datetime import datetime
# identifica se foi consorcio ou financiamento
descritivo_imob_consorcio = np.random.choice(['Consorcio', 'Financiamento'], size=tamanho_base)

# verifica se a pessoa analisada fez o produto financeiro com o parceiro
fl_conjuge = np.random.choice([1, 0], size=tamanho_base)

# sorteia a data de quando o cliente contratou o produto Financeiro
def dataAdesao():
    ano = np.random.randint(2018, 2021)
    mes = np.random.randint(1,12)
    dia = np.random.randint(1,29)
    return datetime(ano, mes, dia)

dt_adesao = [dataAdesao() for i in range(tamanho_base)]

# SORTEIA O ESTADO QUE O CLIENTE FEZ A ADESAO
estados_brasileiros = [
    'Acre', 'Alagoas', 'Amapá', 'Amazonas', 'Bahia', 'Ceará', 'Distrito Federal',
    'Espírito Santo', 'Goiás', 'Maranhão', 'Mato Grosso', 'Mato Grosso do Sul',
    'Minas Gerais', 'Pará', 'Paraíba', 'Paraná', 'Pernambuco', 'Piauí', 'Rio de Janeiro',
    'Rio Grande do Norte', 'Rio Grande do Sul', 'Rondônia', 'Roraima', 'Santa Catarina',
    'São Paulo', 'Sergipe', 'Tocantins'
]

estado_adesao = np.random.choice(estados_brasileiros, size=tamanho_base)

# PORCENTAGEM DO VALOR DO SEGURO do BEM CONTRATADO
porcentagem_seguro =np.random.choice([0.01, 0.05, 0.03], size=tamanho_base, p=[0.7, 0.1, 0.2])

documento_usado = np.random.choice(['RG', 'CPF', 'CNH'], size=tamanho_base)



# TAXA DE JUROS, VALOR SEGURO, STATUS_COTA
trabalhos_comuns = [
    "Analista de Sistemas",
    "Desenvolvedor de Software",
    "Engenheiro de Software",
    "Analista de Dados",
    "Analista Financeiro",
    "Assistente Administrativo",
    "Assistente de Vendas",
    "Assistente de Recursos Humanos",
    "Atendente de Loja",
    "Atendente de Telemarketing",
    "Auxiliar de Limpeza",
    "Auxiliar de Produção",
    "Caixa de Supermercado",
    "Consultor de Vendas",
    "Coordenador de Logística",
    "Estoquista",
    "Recepcionista",
    "Secretário(a)",
    "Técnico de Informática",
    "Técnico de Laboratório",
    "Técnico de Manutenção",
    "Vendedor(a)",
    "Analista de Qualidade",
    "Analista de Suporte Técnico",
    "Assistente de Marketing",
    "Assistente de Recursos Humanos",
    "Atendente de Call Center",
    "Auxiliar Administrativo",
    "Auxiliar de Escritório",
    "Auxiliar de Recursos Humanos",
    "Consultor Financeiro",
    "Coordenador de Vendas",
    "Designer Gráfico",
    "Editor de Conteúdo",
    "Estagiário",
    "Gerente de Contas",
    "Operador de Caixa",
    "Operador de Telemarketing",
    "Programador",
    "Recepcionista",
    "Supervisor de Produção",
    "Técnico de Enfermagem",
    "Técnico de Segurança do Trabalho",
    "Vendedor Externo"
]

cargo = np.random.choice(trabalhos_comuns, size=tamanho_base)

dependentes = np.random.choice(['0', '1', '2', '>3'], size=tamanho_base, p=[0.7, 0.1, 0.1, 0.1])

canal_contratacao = np.random.choice( ['MOBILE', 'DESKTOP', 'AGENCIAS', 'VENDEDORES EXTERNOS'], size=tamanho_base)

lista = {  
'canal_contratacao' :canal_contratacao
,'dependentes' : dependentes
,'cargo' : cargo
,'trabalhos_comuns' : cargo
,'documento_usado' : documento_usado
,'porcentagem_seguro': porcentagem_seguro
,'estado_adesao': estado_adesao
,'dt_adesao': dt_adesao
,'fl_conjuge': fl_conjuge
,'descritivo_imob_consorcio' : descritivo_imob_consorcio
,'CPF_CNPJ':  cpf_cnpj
}

df_contratacoes = pd.DataFrame(lista)
display(df_contratacoes)
# Out:
#           canal_contratacao dependentes                    cargo  \
# 0                  AGENCIAS           0            Recepcionista
# 1                   DESKTOP          >3            Secretário(a)
# 2                  AGENCIAS           1    Coordenador de Vendas
# 3       VENDEDORES EXTERNOS           0  Assistente de Marketing
# 4                   DESKTOP           0   Técnico de Laboratório
# ...                     ...         ...                      ...
# 399995             AGENCIAS           2    Técnico de Enfermagem
# 399996               MOBILE           0               Estoquista
# 399997              DESKTOP          >3        Operador de Caixa
# 399998               MOBILE           1     Auxiliar de Produção
# 399999  VENDEDORES EXTERNOS           1         Vendedor Externo
#
#                trabalhos_comuns documento_usado  porcentagem_seguro  \
# 0                 Recepcionista             CNH                0.01
# 1                 Secretário(a)             CNH                0.01
# 2         Coordenador de Vendas             CNH                0.01
# 3       Assistente de Marketing             CPF                0.01
# 4        Técnico de Laboratório              RG                0.03
# ...                         ...             ...                 ...
# 399995    Técnico de Enfermagem             CPF                0.01
# 399996               Estoquista             CNH                0.01
# 399997        Operador de Caixa              RG                0.05
# 399998     Auxiliar de Produção             CPF                0.01
# 399999         Vendedor Externo              RG                0.05
#
#              estado_adesao  dt_adesao  fl_conjuge descritivo_imob_consorcio  \
# 0                   Paraná 2019-03-27           1             Financiamento
# 1                     Acre 2018-05-15           1                 Consorcio
# 2                     Acre 2018-05-01           1             Financiamento
# 3                  Alagoas 2018-04-02           1             Financiamento
# 4           Espírito Santo 2019-11-02           0                 Consorcio
# ...                    ...        ...         ...                       ...
# 399995               Goiás 2020-10-02           1             Financiamento
# 399996               Amapá 2020-11-05           0                 Consorcio
# 399997             Alagoas 2019-04-22           1             Financiamento
# 399998               Piauí 2018-08-26           1                 Consorcio
# 399999  Mato Grosso do Sul 2019-01-24           0             Financiamento
#
#          CPF_CNPJ
# 0       155907201
# 1       382250632
# 2       349145899
# 3       751489071
# 4       257310413
# ...           ...
# 399995  088847205
# 399996  888130488
# 399997  033478755
# 399998  269702184
# 399999  537488892
#
# [400000 rows x 11 columns]

# %% [markdown]
# # BASE DE PROPOSTAS

# %%
aprovacao = np.random.choice(['Aprovada pelo Motor', 'Aprovada por analista', 'Reprovado'], size=tamanho_base)

df_informacoes_produtos = pd.DataFrame()
